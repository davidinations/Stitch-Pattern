# %% [markdown]
# ##### Metrics for Classification Sticth Fabric Detection
# - Accuracy (Most Important)
# - F1 Score
# - Precision
# - Recall
# - Time Complexity (Important)
# - ROC AUC (Optional)
# - Kappa (Optional)
# - MCC (Optional)

# %%
import imutils, os, cv2, pickle
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image

# Open an image file
image_rgb = cv2.imread('dataset/straight/1.jpeg')

plt.imshow(image_rgb)
plt.show()

# %%
import numpy as np
import cv2 as cv
import matplotlib.pyplot as plt

filename = '1.jpeg'
img = cv.imread(filename)
gray = cv.cvtColor(img,cv.COLOR_BGR2GRAY)

# Use the Canny edge detection method
edges = cv.Canny(gray,50,150,apertureSize = 3)

# Use the Hough Line Transform method to detect lines
lines = cv.HoughLines(edges,1,np.pi/180,200)

# Draw the lines on the original image
for rho,theta in lines[:,0]:
    a = np.cos(theta)
    b = np.sin(theta)
    x0 = a*rho
    y0 = b*rho
    x1 = int(x0 + 1000*(-b))
    y1 = int(y0 + 1000*(a))
    x2 = int(x0 - 1000*(-b))
    y2 = int(y0 - 1000*(a))

    cv.line(img,(x1,y1),(x2,y2),(0,0,255),2)

# Convert color from BGR to RGB
img_rgb = cv.cvtColor(img, cv.COLOR_BGR2RGB)

# Display the image using matplotlib
plt.imshow(img_rgb)
plt.show()

# Print the number of lines
print('Number of lines:', len(lines))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[5], line 16
#      13 lines = cv.HoughLines(edges,1,np.pi/180,200)
#      15 # Draw the lines on the original image
# ---> 16 for rho,theta in lines[:,0]:
#      17     a = np.cos(theta)
#      18     b = np.sin(theta)
#
# TypeError: 'NoneType' object is not subscriptable
