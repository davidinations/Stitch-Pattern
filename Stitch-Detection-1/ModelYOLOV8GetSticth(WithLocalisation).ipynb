# %%
# import torch
# import torchvision
# print(torch.__version__)
# print(torchvision.__version__)

# %%
# import tensorflow as tf
# from tensorflow.python.client import device_lib
# tf.config.list_physical_devices('GPU')
# device_lib.list_local_devices()

# %%
import torch
print(torch.cuda.is_available())
# Out:
# True

# %% [markdown]
# ### Text above just for testing setup with the GPU

# %%
from ultralytics import YOLO

# %%
# Load model
model = YOLO("yolov8s-seg.pt")
# model.to('cpu')
# Out:
# ...
# 100%|██████████| 22.8M/22.8M [00:50<00:00, 474kB/s]

# %%
# import gc
# import torch

# # Define a function to train the model and clear memory after each epoch
# def train_and_clear(model, data, epochs):
#     for epoch in range(epochs):
#         model.train(data, epochs=1)

#         # Clear PyTorch CUDA cache if PyTorch is used
#         if torch.cuda.is_available():
#             torch.cuda.empty_cache()

#         # Manually trigger garbage collection
#         gc.collect()

# # Train model
# train_and_clear(model, data="data.yaml", epochs=30)

# %%
# Train model
model.train(data="data.yaml", epochs=100, batch=3)
torch.cuda.empty_cache()
# Out:
# New https://pypi.org/project/ultralytics/8.2.18 available  Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.0.196  Python-3.9.18 torch-2.3.0+cu121 CUDA:0 (NVIDIA GeForce GTX 1060, 6144MiB)
# ...

# %%
# # Apply Model to Images
# results = model("dataset_stitch_detection")  # or img.jpg, or list of images
# results.show()  # display results
